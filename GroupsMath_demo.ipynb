# %% [markdown]
# # **A swift introduction to group theory with *GroupsMath***
#
# ![GroupsMath Logo](https://raw.githubusercontent.com/MarioSultan/GroupsMath/main/logo.png)
#
# **GroupsMath** is a Python module for constructing, studying, and manipulating finite and infinite groups.
#
# The project aims to provide a simple and intuitive interface for working with groups and their algebraic properties.
#
# ---

# %% [markdown]
# ## The first step: importing the library
#
# GroupsMath is currently distributed through [PyPI](https://pypi.org/project/GroupsMath/) and [Github](https://github.com/MarioSultan/GroupsMath).
# To import the library, run the following:

# %%
from groupsmath import *                # The core library

from groupsmath.precooked import *      # Lots of basic groups we're going to use

# %% [markdown]
# See the information of the version you have imported with:

# %%
groupsmath_info()
# Out:
# ———————————————————————————————————————————————————————————————————————————
#
#                           > GroupsMath v0.7.2
#               The educational Python library for Group Theory
#
# GroupsMath is a Python module for constructing, studying, and manipulating
# finite groups. The project aims to provide a simple and intuitive interface
# for working with finite groups and their algebraic properties.
#
# You can view all the information of the proyect in PyPI and GitHub:
# · PyPI https://pypi.org/project/GroupsMath/
# · GitHub https://github.com/MarioSultan/GroupsMath
#
# The documentation of this library is in the following link:
# · Documentation https://groupsmath.readthedocs.io/en/latest/
#
# ———————————————————————————————————————————————————————————————————————————

# %% [markdown]
# ---

# %% [markdown]
# ## **1. Creating groups**
#
# In GroupsMath there exist a lot of methods to create groups, the more basic one is using the precooked groups that are avaliable at the library `groupsmath.precooked`. We'll start with the group $C_6$, its elements have the form:
#
# $$ r^k, \text{with } 0\le k < 6 $$
#
# That is: $r^0$, $r$, $r^2$, $r^3$, $r^4$ and $r^5$, where $r^0$ is commonly known as $e$ (the identity element of $C_6$).
#
# To create this group in GroupsMath simply write `C6`, and that's it. Let's visualize its elements!

# %%
print(C6.elements)      # In Python, "print" means "show me what I'm asking you for", in this case, "show me C6.elements".
# Out:
# ['e', 'r', 'r^{2}', 'r^{3}', 'r^{4}', 'r^{5}']

# %% [markdown]
# **✏️ Challenge:** *Can you get the names of the elements in the group $C_8$*?

# %%
# Write your code here

# %% [markdown]
# ---

# %% [markdown]
# ## **2. Operating with elements**
#
# Once we know some basic groups, we can do operations with its elements. First, we have to create a variable that represents the element. For example, the following code says "`a` represents the element `'r'` in $C_6$".

# %%
a = Element('r',C6)

# %% [markdown]
# **✏️ Challenge:** *Can you create a variable `b` representing the element `'r^{3}'` in $C_6$*?

# %%
# Write your code here

# %% [markdown]
# Now, we can operate `a` and `b` in the frame of $C_6$. The operation of elements is done using `*`.

# %%
b = Element('r^{3}',C6) # If you wrote this line in the last challenge, congratulations!

print(a*b)
# Out:
# r^{4}

# %% [markdown]
# The result of `a` times `b` is `r^{4}`, which is logical because:
#
# $$r*r^3=r^4$$

# %% [markdown]
# **✏️ Challenge:** *Can you print the result of the operation $b*b$?*

# %%
# Write your code here

# %% [markdown]
# What happened? The code you wrote says $r^3*r^3=e$, is it wrong?
#
# No, it's completely correct. The group $C_6$ hold the equivalence $r^6=e$, that's why its name is $C_6$. In **group theory**, every group has a set of elements and a operation between them that satisfies some relations, for example $C_6$ holds $r^6=e$.
#
# Welcome to ***group theory***, where ***GroupsMath*** is your best ally.

# %%
# You can try writing here the code you want. Experiment with groups and its elements :)

# %% [markdown]
# ---

# %% [markdown]
# ## **3. Visualizing operations and abelianity**
#
# It would be great if there were a way to simultaneously view all possible operations between all the elements of a group. Well, such a thing does exist, and it is known as a "Cayley table."
#
# A Cayley table is a matrix-shaped chart where each square represents the result of operating the element of his row with the element of his column.
#
# GroupsMath can do it, do you want to se the Cayley table of $C_6$? Just write:

# %%
C6.cayley_table()

# %% [markdown]
# **✏️ Challenge:** *Can you get the Cayley table of the group $C_4$?*

# %%
# Write your code here

# %% [markdown]
# As you have seen, both tables are symmetric, that is, it always stand that $r^a*r^b=r^b*r^a$. The groups whit this characteristic are known as *abelian groups*. The $C_n$ groups (known as *cyclic groups*) are all abelian: $C_1$, $C_2$, $C_3$, $C_4$, ...
#
# And you might be wondering: are there any non-abelian group?
#
# Yes, in fact, the bast majority of the groups are non-abelian. For example, the group $S_3$ is not abelian.

# %% [markdown]
# **✏️ Challenge:** *Can you get the Cayley table of the group $S_3$?*
# > 💡 Hint: try using `S3` as the group name.

# %%
# Write your code here

# %% [markdown]
# You will have noticed that, in addition to the element names being different, the Cayley table is no longer symmetric, therefore, you have seen that the group $S_3$ **is not** an abelian group.
#
# Now, you can try generating the Cayley tables of other types of groups and see if they are or not abelian. GroupsMath has the following predefined groups, as shown in the next chart.
#
# 📚 If you want to create a group that is not in the chart, you can visit [Group_families_and_precooked_groups.md](https://groupsmath.readthedocs.io/en/latest/Group_families_and_precooked_groups/) or the whole [GroupsMath documentation](https://groupsmath.readthedocs.io/en/latest/).

# %% [markdown]
# ### Available Precooked Groups List
#
# | Family | Instances Available | Examples & Description |
# | :--- | :--- | :--- |
# | **Trivial Group** | `I` | The trivial group containing only the identity element `e`. |
# | **Cyclic Groups** | `C1` through `C20` | `C5` represents $C_5$, with element names `['e', 'r', 'r^{2}', 'r^{3}', 'r^{4}']`. |
# | **Symmetric Groups** | `S1`, `S2`, `S3`, `S4` | `S3` represents $S_3$ (order 6), `S4` represents $S_4$ (order 24). |
# | **Alternating Groups** | `A1`, `A2`, `A3`, `A4` | `A4` represents $A_4$ (order 12) with cycle notation. |
# | **Dihedral Groups** | `D1` through `D10` | `D4` represents $D_4$ (order 8) with elements `e`, `r`, `s`, ... |
# | **Units Groups Modulo $n$** | `U2` through `U20` | The identity element ($e$) is represented here as "$1$". |
# | **Klein Four-Group** | `V4` | Klein 4-group with names `["e", "a", "b", "ab"]`. |
# | **Quaternion Group** | `Q8` | The identity element ($e$) is represented here as "$1$". |
# | **Dicyclic Groups** | `Dic2`, `Dic3` | Dicyclic groups of order $4n$ ($\text{Dic}_2$ has order 8, $\text{Dic}_3$ order 12). |

# %%
# Give it your all here, code what you want.

# %% [markdown]
# 📚 If you want learn more about Cayley tables on GroupsMath, visit the [GroupsMath documentation](https://groupsmath.readthedocs.io/en/latest/Cayley_table_visualization/).

# %% [markdown]
# ---

# %% [markdown]
# ## **4. Exploring elements inside groups**
#
# ### 4.1. Order of a group
#
# GroupsMath provides many tools to explore the characteristics of any group you can imagine. The first thing we are going to see is the **order** of a group. The order of a group is defined as the number of elements it has. For example, $C_6$ has 6 elements ($e$, $r$, $r^2$, $r^3$, $r^4$ and $r^5$).

# %%
print(C6.order())
# Out:
# 6

# %% [markdown]
# **✏️ Challenge:** *Find the order of the group $S_3$*

# %%
# Write you code here

# %% [markdown]
# As you can see, the fact that two groups have the same order does not imply that they are the same group. Mathematically this is written as follows:
#
# $$C_6\ncong S_3$$
#
# > **Note:** The symbol "$\cong$" is used when to groups has the same estructure (and the groups are called *isomorphic*), meanwhile, if two groups are not isomorphic is written "$\ncong$".

# %% [markdown]
# **✏️ Challenge:** *Find the orders of the groups $A_4$, $D_5$ and $Q_8$*

# %%
# Write your code here, you will need to write more than one line of code.

# %% [markdown]
# ### 4.2. Identity element of a group
#
# Every group has one —and only one— **identity element**, commonly represented as $e$ (but not always), that satisfies:
#
# $$a*e=a \:\text{ for all elements in the group}$$
#
# That is, multiplying any element with the identity results in the same element.
#
# To find the identity element of a group, for example $C_6$, write:

# %%
print(C6.identity())
# Out:
# e

# %% [markdown]
# In some groups, the identity is not written traditionally as $e$.

# %% [markdown]
# **✏️ Challenge:** *Find the identity element of the group $Q_8$*

# %%
# Write your code here

# %% [markdown]
# ### 4.3. Inverses
#
# Given an element $a$, you can ask "which element should I operate $a$ with to get the identity element?" This element is called the **inverse element** of $a$ (usually written as $a^{-1}$). In GroupsMath is very easy to compute it. We will take $C_6$ as example.

# %%
a = Element('r',C6)     # Create the element

b = a.inverse()         # Define the element "b" as the inverse of "a"

print(b)                # Print "b"
# Out:
# r^{5}

# %% [markdown]
# The reasoning behind this is that $C_6$ has the relation $r^6=e$.
#
# $$r*r^5=r^6=e\:\Rightarrow\:(r)^{-1}=r^5$$

# %% [markdown]
# Furthermore, the inverse of an element can be itself; try $r^{3}$.
#
# **✏️ Challenge:** *Create a variable representing `'r^{3}'` in the group $C_6$, find its inverse and print it.*

# %%
# Write your code here

# %% [markdown]
# **⭐ Difficult challenge:** *Create a variable `a` representing the element `'(123)'` of $S_4$, define a variable `b` as its inverse and print it. Then, print the operation $a*b$ to check that the result is the identity element.*

# %%
# Write your code here

# %% [markdown]
# ### 4.4. Power of elements
#
# An element can be operated with itself many times, this is the definition of a **power**.
#
# $$\underbrace{r*r*\cdots*r}_{k\text{ times}}=r^k$$
#
# In GroupsMath its computed using the `**` operator.

# %%
a = Element('r^{2}',C6)     # Defining "a" as the element 'r^{2}'

print(a**2)                 # Print a**2
# Out:
# r^{4}

# %% [markdown]
# The result satisfies the relations of the group, for example, if $C_6$ has the relation $r^6=e$, then:
#
# $$(r^2)^3=r^2*r^2*r^2=r^6=e$$

# %%
# Try this here

# %% [markdown]
# **✏️ Challenge:** *Create a variable `a` representing the element `'(123)'` of $S_4$ and print $a^3$. What is the result?*

# %%
# Write your code here

# %% [markdown]
# ### 4.5. Order of elements
#
# If you multiply it by itself a given number of times, you will always obtain the identity element ($e$). The smallest number for which this happens is known as the **order** of the element. Use GroupsMath to compute the order of any element.

# %%
a = Element('r^{2}',C6)     # Create the element

print(a.order())            # Print its order
# Out:
# 3

# %% [markdown]
# Logically, it is true for any element that:
#
# $$a^{\text{order}(a)}=e$$

# %% [markdown]
# **⭐ Difficult challenge:** *Create a code that, given an element $a$ (defined as a variable), prints the result of $a^{\text{order}(a)}$. Try your code with multiple elements and multiple groups to see that it is always true.*

# %%
# Write your code here

# %% [markdown]
# **⭐⭐ Difficult challenge:** *Write a code that, given an element $a$ (defined as a variable) in a group $G$, prints the result of $a^{\text{order}(G)}$, where $\text{order}(G)$ is the order of the group. Try your code with multiple elements and multiple groups to see what happens. Think about why this happens and research it on the internet.*
# >💡 Hint: You are proving Lagrange's theorem using GroupsMath.

# %%
# Write your code here

# %% [markdown]
# 📚 If you want learn more about elements on GroupsMath, visit the [GroupsMath documentation](https://groupsmath.readthedocs.io/en/latest/Elements/).

# %% [markdown]
# ---

# %% [markdown]
# ## **5. Exploring groups**
#
# GroupsMath provides lots of methods to explore almost any group you want. We will see the more basic ones, such as tha isomorphy, the abelianity, the generators and Cayley graphs (yes, there exist Cayley tables and graphs).
#
# ### 5.1. Isomorphy
#
# Two groups $A$ and $B$ are isomorphic if they have the same structure, even if their elements are different or represented in different ways.
#
# Imagine that you have two groups that look completely different. An **isomorphism** is a way of matching the elements of one group with the elements of the other such that the group operation is preserved.
#
# In other words, if two elements combine in a certain way in the first group, their corresponding elements must combine in exactly the same way in the second group.
#
# So, from the point of view of group theory, **isomorphic groups are essentially the same group written in different ways**. We write:
#
# $$A\cong B$$
#
# For example, the group $C_3$ and $A_3$ are isomorphic.

# %% [markdown]
# **✏️ Challenge:** *Make the Cayley table of $C_3$ and the one of $A_3$, then compare them. What is the difference?*

# %%
# Write your code here

# %% [markdown]
# As you see, despite of the groups having different names, their cayley table –and their structure– are essentialy the same.
#
# You can verify if two groups are isomorphic using GroupsMath, just write:

# %%
print(are_isomorphic(C3,A3))        # Showing if C3 and A3 are isomorphic
# Out:
# True

# %% [markdown]
# It says `True`, which means that $C_3\cong A_3$. Now try:

# %%
print(are_isomorphic(C3,S3))
# Out:
# False

# %% [markdown]
# It says `False`, so $C_3\ncong S_3$.

# %% [markdown]
# **⭐ Difficult challenge:** *Make a program that finds which of the groups of the list $[C_2,C_3,C_6,V_4,A_3,S_3,Q_8]$ is isomorphic to $D_3$. If you know a little Python, try making a `for` loop to find it.*

# %%
groups = [C2,C3,C6,V4,A3,S3,Q8]     # You can use this list if you want

# Write your code here

# %% [markdown]
# ### 5.2. Abelianity
#
# As we previously said, a group $G$ is abelian if every pair of elements $a$ and $b$ satisfy:
#
# $$a*b=b*a$$
#
# GroupsMath says if a group is abelian or not with the function `.is_abelian()`. For example, with $C_6$:

# %%
print(C6.is_abelian())      # Showing if C6 is abelian
# Out:
# True

# %% [markdown]
# **✏️ Challenge:** *Is the group $C_8$ abelian? And $S_3$? And $V_4$?*

# %%
# Write your code here

# %% [markdown]
# ### 5.3. Generators of a group
#
# Every group has a set of elements that generate every other element of the group via the operation of the group. For example, $C_6$ has the elements $e$, $r$, $r^2$, $r^3$, $r^4$ and $r^5$. You can see that the element $r$ can generate every other element in $C_6$ only operating with itself repeatedly.
#
# $$r=r$$
# $$r^2=r*r$$
# $$r^3=r*r*r$$
# $$r^4=r*r*r*r$$
# $$r^5=r*r*r*r*r$$
# $$e=r*r*r*r*r*r$$
#
# Then, $r$ is a **generator** of $C_6$. The number of elements that a group needs *at least* to be generated is called its **rank**.
#
# $$\text{rank}(C_6)=1$$
#
# Any cyclic group ($C_n$) can be generated using only one generator. Furthermore, every group that can be generated with only one generator is isomorphic with a cyclic group. Mathematically, is written as:
#
# $$\text{rank}(G)=1 \Longleftrightarrow \exists n:G\cong C_n$$

# %% [markdown]
# **✏️ Challenge:** *Compute the generators of $S_3$. Is cyclic?*

# %%
# Write your code here

# %% [markdown]
# **✏️ Challenge:** *Compute the generators of $A_3$. Is cyclic?*

# %%
# Write your code here

# %% [markdown]
# Also, you can compute the rank of a group using `.rank()`, for example:

# %%
print(S3.rank())

# %% [markdown]
# ### 5.4. Cayley graphs
#
# The Cayley graph of a group are is very effective method to see its structure.
#
# The nodes (dots) represents the elements, and the arrows represents which generator you have to multiply the element by for reaching other element. For example,
#
# $$r^2 \xrightarrow{r} r^3$$
#
# means that you obtain $r^3$ multiplying $r^2$ by the generator $r$.
#
# In GroupsMath, tha Cayley graphs are constructed writing `.cayley_graph()`. Let's visualize the Cayley graph of $C_6$:

# %%
C6.cayley_graph()

# %% [markdown]
# It's cylic, so it can be generated using onli one geneator (shown in red). Now compare it with the Cayley graph of $S_3$:

# %%
S3.cayley_graph()

# %% [markdown]
# It has the same number of elements as $C_6$, but its internal structure is not the same, therefore:
#
# $$C_6\ncong S_3$$

# %% [markdown]
# **⭐ Difficult challenge:** *Identify which of the groups of the list $[V_4,D_4,A_3,S_3,Q_8]$ is/are cyclic by doing **only** Cayley graphs.*

# %%
# Write your code here

# %% [markdown]
# 📚 If you want learn more about Cayley graphs on GroupsMath, visit the [GroupsMath documentation](https://groupsmath.readthedocs.io/en/latest/Cayley_graphs/).

# %% [markdown]
# ---

# %% [markdown]
# ## **6. Subgroups**
#
# Can there be a group inside another group? To find this we have to know what's is a group mathematically speaking.
#
# ### 6.1. Mathematical definition of a group
# So far, you have been computing various things with groups, and basically what you have done is perform operations on their elements. Then, a group is made up of a set (let's call it $M$) and an operation (represented as $*$). Therefore, a group $G$ is:
#
# $$G=(M,*)$$
#
# But, the operation must satisfy some axioms:
#
# - **Closure:** First of all, the elements we use to perform operations are those that belong to the set $M$, so if we want to keep performing operations later on, it is logical to require that the result also be in $M$. This is:
#
# $$a,b\in M\:\Longrightarrow a*b\in M$$
#
# - **Identity:** Secondly, as you already know, every group must have its identity element ($e$). This is:
#
# $$\exists!e\in M:\quad a*e=e*a=a$$
#
# - **Inverses:** Also, as you have already experienced before in the code, every element must have its inverse.
#
# $$\forall a\in M,\quad \exists a^{-1}\in M:\quad a*a^{-1}=e$$
#
# - **Associativity:** And lastly, to avoid any headaches, the operation is required to be associative.
#
# $$\forall a,b,c\in M,\quad (a*b)*c=a*(b*c)$$

# %% [markdown]
# For example, we can verify the associativity of three elements of $C_6$ using GroupsMath.

# %%
a = Element('r',C6)         # Defining "a" as 'r'
b = Element('r^{3}',C6)     # Defining "b" as 'r^{3}'
c = Element('r^{4}',C6)     # Defining "c" as 'r^{4}'

print( (a*b)*c )            # Showing (a*b)*c
print( a*(b*c) )            # Showing a*(b*c)
# Out:
# r^{2}
# r^{2}

# %% [markdown]
# As you see, the result is the same in both cases, $r^2$.

# %% [markdown]
# **✏️ Challenge:** *Define any three elements you want from any group you want ($C_n$,$A_n$,$S_n$,...), and verify that associativity holds.*

# %%
# Write your code here

# %% [markdown]
# ### 6.2. Defining a subgroup
#
# Since you already know what a group is, a subgroup is nothing more than a group inside another. If $S$ is a subgroup of $G$ (i.e. $S$ is inside $G$ and $S$ is itself a group), we write:
#
# $$S\le G$$
#
# Since the subgroup is inside the parent group, associativity is automatically inherited because the operation works the same way for all elements. This means you don't need to check it again.
#
# In fact, the only thing you really need to check is **closure**, ensuring that when you operate any elements of $S$, the result always remains inside $S$.
#
# For example, $C_6$ has the elements $e$, $r$, $r^2$, $r^3$, $r^4$ and $r^5$. You can make the set $T=\{e,r^2,r^4\}$ and operate every element of $T$ with every other element of $T$:
#
# $$e*e=e     \qquad  e*r^2=r^2       \qquad  e*r^4=r^4$$
# $$r^2*e=r^2 \qquad  r^2*r^2=r^4     \qquad  r^2*r^4=e$$
# $$r^4*e=r^4 \qquad  r^4*r^2=e       \qquad  r^4*r^4=r^2$$
#
# Every result is also in $T$, so the group $(T,*)$ is a subgroup of $C_6$.
#
# $$(T,*)\le C_6$$
#
# > **Note:** Remember that a group is made up of the set ($T$) and the operation ($*$). $T$ is the set of elements and $(T,*)$ is the subgroup.
#
# Logically, every group is a subgroup of itself, and the identity group ($I$, consisting only of the identity element) is also always a subgroup.
#
# $$G\le G    \qquad  I\le G$$

# %% [markdown]
# GroupsMath can show you all the subgroups of every group you want. The subgroups of a group `G` are obtained with `G.subgroups()`. To see the elements of all the subgroups of $C_6$ we need to make a `for` loop in Python. If you don't know how to use `for` loops, read the note below.

# %%
for S in C6.subgroups():
    print(S.elements)
# Out:
# ['e']
# ['e', 'r^{3}']
# ['e', 'r^{2}', 'r^{4}']
# ['e', 'r', 'r^{2}', 'r^{3}', 'r^{4}', 'r^{5}']

# %% [markdown]
# > **Note:** A `for` loop is just a way to repeat an action for every item in a list. In the code above, `C6.subgroups()` gives us a collection of all the subgroups. The loop takes the first subgroup, calls it `S`, and prints its elements. Then, it automatically moves to the next subgroup and does the same, repeating this process until it finishes the entire list.

# %% [markdown]
# You can see that the subgroups of $C_6$ consist of the following elements:
#
# $I$ — `['e']`
#
# $C_2$ — `['e', 'r^{3}']`
#
# $C_3$ — `['e', 'r^{2}', 'r^{4}']`
#
# $C_6$ — `['e', 'r', 'r^{2}', 'r^{3}', 'r^{4}', 'r^{5}']`
#
# The group we found previously, $(T,*)$ with $T=\{e,r^2,r^4\}$, was isomorphic to $C_3$. So $C_3$ is a subgroup of $C_6$.

# %% [markdown]
# **✏️ Challenge:** *Make a `for` loop to show all the subgroups of $S_3$.*

# %%
# Write your code here

# %% [markdown]
# **⭐ Difficult challenge:** *Make a `for` loop of the subgroups of a cyclic group as $C_{12}$. Print the rank of every subgroup. What is the result? What is the meaning of this?*
# >💡 Hint: What makes a group *cyclic*?

# %%
# Write your code here

# %% [markdown]
# **⭐⭐ Difficult challenge:** *Take the group $U_{15}$ (`U15` in GroupsMath), which is abelian. Then, make a loop for computing if all of its subgroups are also abelian. What is the result? Why does this happen?*
# >💡 Hint: Property inheritance.

# %%
# Write your code here

# %% [markdown]
# 📚 If you want learn more about subgroups on GroupsMath, visit the [GroupsMath documentation](https://groupsmath.readthedocs.io/en/latest/Subgroups/).

# %% [markdown]
# ---

# %% [markdown]
# ## **7. Direct product**
#
# ### 7.1. Definition of the direct product
#
# We have seen that we can find groups inside other groups, but can we combine groups to form new ones? This is the core idea behind the *direct product* of groups. Imagine you have two different groups, let's call them $G$ and $H$. To create a new group using the direct product, you simply pair their elements up. The elements of this new group will look like $(g, h)$, where $g$ comes from $G$ and $h$ comes from $H$. The resulting group is called the **direct product group**.
#
# $$G \times H$$
#
# To do operations in this new group, you just work component by component. You combine the first elements using the operation of group $G$, and the second elements using the operation of group $H$. It is that simple! The identity element is just the pair of both identities, and the inverse is just the pair of both inverses.
#
# $$(g_1,h_1)*(g_2,h_2) = (g_1*g_2,h_1*h_2)$$
#
# Let's make the Cayley graph of $C_2$, this is:

# %%
C2.cayley_graph()

# %% [markdown]
# Now the direct product of two groups in GroupsMath is made with the operator `*`. For example `C2*C2` means $C_2\times C_2$.

# %%
G = C2*C2           # Define the direct product group

G.cayley_graph()    # Show the Cayley graph

# %% [markdown]
# **✏️ Challenge:** *Construct the Cayley table and the Cayley Graph for the group $C_2\times C_4$.*

# %%
# Write your code here

# %% [markdown]
# Also you can make multiple direct products in a row, what is called a **direct power**
#
# $$G^n = \underbrace{G \times G \times \dots \times G}_{n \text{ times}}$$
#
# In GroupsMath is represented by the `**` operator, for example ``C2**2`` represents $C_2\times C_2$ and ``C2**3`` represents $C_2\times C_2\times C_2$.

# %% [markdown]
# **✏️ Challenge:** *Construct the Cayley table and the Cayley Graph for the group $C_2^3$. What do you see? What is the rank of this group?*

# %%
# Write your code here

# %% [markdown]
# **⭐ Difficult challenge:** *Construct the Cayley Graph for the group $C_3\times S_3$. Then make the one of $S_3\times C_3$. Are this two direct product groups isomorphic?*
#
# >💡 Hint: If you don't see the isomorphy, use the function `are_isomorphic()`.

# %%
# Write your code here

# %% [markdown]
# ### 7.2. Isomorphy of direct product groups
#
# In the last challenge you discovered that, for two groups $G$ and $H$, is always true that:
#
# $$G \times H \cong H \times G$$
#
# However, there are many other interesting isomorphisms when talking about direct product groups. For example, we are going to compare the groups $C_2\times C_2$ and $V_4$ (which is known as **Klein group**).

# %%
(C2*C2).cayley_graph(title="Graph of C2xC2")        # We create the Cayley graph of C2*C2 and add a title to distinguish it better.

V4.cayley_graph(title="Graph of V4")                # The same but with the Klein group.

# %% [markdown]
# **⭐ Difficult challenge:** *Construct the Cayley Graph for the group $D_6$ (`D6`). And compare it with the graph of $S_3\times C_2$. Do you see the isomorphy? Use the function `are_isomorphic()` to verify it.*

# %%
# Write your code here

# %% [markdown]
# **⭐⭐⭐ Final challenge:** *Think in cyclic groups ($C_n$), you can make products with them, like $C_2\times C_3$ or $C_4\times C_{12}$. Use all you have learned of GroupsMath to find when the the statement $C_a\times C_b\cong C_{a\times b}$ is true. Experiment with the code, you can use GroupsMath functions, `for` loops or whatever you want.*
#
# >💡 Hint: Look at the relation betwenn $a$ and $b$ when is satisfied that $C_a\times C_b\cong C_{a\times b}$.

# %%
# Try your best here. This challenge is not easy, but you can do it! :)

# %% [markdown]
# 😊 If you prefer to tackle the challenge at your own pace, you can install GroupsMath [here](https://pypi.org/project/GroupsMath/).
#
# 📚 If you want learn more about products on GroupsMath, visit the [GroupsMath documentation](https://groupsmath.readthedocs.io/en/latest/Products/).

# %% [markdown]
# ---

# %% [markdown]
# ## **What is left now?**
#
# Congratulations! You have completed the introduction to group theory with GroupsMath.
#
# But this is only the beginning.
#
# You have learned how to construct groups, work with their elements and operations, find subgroups, explore symmetries, and visualize their structure. You have even started to see how much information can be hidden inside a seemingly simple algebraic object.
#
# So... **what comes next?**
#
# There is much more to discover:
#
# * Can we systematically describe all the symmetries of a group?
# * What does it mean to quotient a group by a subgroup?
# * How do groups reveal the structure of geometric objects?
# * How many groups are there?
# * How strange can a group be?
# * And perhaps most importantly: **how far can we push GroupsMath?**
#
# The answers lead to some of the most beautiful ideas in modern mathematics.
#
# ---
#
# ### **Your journey doesn't end here.**
#
# The notebook has shown you a little fraction of what GroupsMath can do.
#
# Now it's time to see what **you** can do with it.
#
# Install GroupsMath, explore its documentation, experiment with your own groups, and try to go beyond the examples in this demo.
#
# 👉 [Install GroupsMath with PyPI](https://pypi.org/project/GroupsMath/)
#
# 👉 [Explore GroupsMath documentation](https://groupsmath.readthedocs.io/en/latest/)
#
# **Come on, the groups are waiting!**

# %% [markdown]
# ---

# %% [markdown]
# # **Thank you for trying GroupsMath ☺**
